# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:32, 5.20MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    return (x*1.0/x.max())


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    #print(x)
    #print(len(x))
    x_one_hot = np.zeros((len(x), 10))
    #print (x_one_hot.shape)
    #print (x_one_hot[:10])
    for i,j in enumerate(x):
        x_one_hot[i,j] = 1
    #print(x_one_hot[:3])
    #print("-------------")
    return x_one_hot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    #tensor = [None] + list(image_shape)
    #print(tensor) 
    return tf.placeholder(tf.float32, [None] + list(image_shape), "x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    #print (n_classes)
    return tf.placeholder(tf.float32, [None,n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, None, "keep_prob")



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    print('[conv2d_maxpool] x_tensor.shape', x_tensor.shape)
    print('[conv2d_maxpool] conv_ksize:', conv_ksize) 
    print('[conv2d_maxpool] conv_num_outputs:', conv_num_outputs)
    print('[conv2d_maxpool] conv_strides:', conv_strides)
    
    dimension = x_tensor.get_shape().as_list()
    shape = list(conv_ksize + (dimension[-1],) + (conv_num_outputs,))
    
    #print('[conv2d_maxpool] shape:', shape)
       
    # Imp--> Set the mean and sd (Its all about initializing the weights!)***
    filter_weights = tf.Variable(tf.truncated_normal(shape, mean=0.0, stddev = 0.1)) # (height, width, input_depth, output_depth)
    #print ('[filter_weights]:',filter_weights)
    filter_bias = tf.Variable(tf.truncated_normal([conv_num_outputs]))
    #print ('[filter_bias.shape]:',filter_bias.shape)
    
    # Convolution
    conv_layer = tf.nn.conv2d(x_tensor, filter_weights, strides=[1] + list(conv_strides) + [1], padding='SAME')
    # Bias
    conv_layer = tf.nn.bias_add(conv_layer, filter_bias)
    # Non Linear
    conv_layer = tf.nn.relu(conv_layer)
        
    # Max Pool
    print('[conv2d_maxpool] pool_ksize:', pool_ksize)
    print('[conv2d_maxpool] pool_strides:', pool_strides, '\n')
    conv_layer = tf.nn.max_pool(conv_layer,
        ksize=[1] + list(pool_ksize) + [1],
        strides=[1] + list(pool_strides) + [1],
        padding='SAME')
    
    return conv_layer



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# [conv2d_maxpool] x_tensor.shape (?, 32, 32, 5)
# [conv2d_maxpool] conv_ksize: (2, 2)
# [conv2d_maxpool] conv_num_outputs: 10
# [conv2d_maxpool] conv_strides: (4, 4)
# [conv2d_maxpool] pool_ksize: (2, 2)
# [conv2d_maxpool] pool_strides: (2, 2)
#
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
from numpy import prod

def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    dimension = x_tensor.get_shape().as_list()  
    #print(dimension)
    flatten = tf.reshape(x_tensor,[-1,prod(dimension[1:])])
    #print(flatten)
    return flatten


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dimension = x_tensor.get_shape().as_list()
    #print (dimension[-1],)
    shape = list( (dimension[-1],) + (num_outputs,))
    #print(shape)
    weight = tf.Variable(tf.truncated_normal(shape, mean=0.0, stddev = 0.1))
    #print(weight)
    bias = tf.Variable(tf.zeros(num_outputs))
    fully_connected = tf.nn.relu(tf.add(tf.matmul(x_tensor,weight),bias))
    #print (fully_connected)
    return fully_connected

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dimension = x_tensor.get_shape().as_list()
    shape = list( (dimension[-1],) + (num_outputs,))
    
    #print(shape)
    weight = tf.Variable(tf.truncated_normal(shape, mean=0.0, stddev = 0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor,weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    #conv 1
    conv_num_outputs = 32
    conv_ksize = (8,8) 
    conv_strides = (1,1)
    pool_ksize = (2,2) 
    pool_strides = (2,2)
    
    conv_layer = conv2d_maxpool(x,conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    #conv 2
    
    conv_num_outputs = 64
    conv_ksize = (4,4) 
    conv_strides = (1,1)
    pool_ksize = (2,2) 
    pool_strides = (2,2)
    
    conv_layer = conv2d_maxpool(conv_layer,conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    #conv 3
    
    conv_num_outputs = 256
    conv_ksize = (2,2) 
    conv_strides = (1,1)
    pool_ksize = (2,2) 
    pool_strides = (2,2)
    
    conv_layer = conv2d_maxpool(conv_layer,conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    conv_layer = flatten(conv_layer)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    num_outputs_fc = 512
    conv_layer = fully_conn(conv_layer, num_outputs_fc)
    
    # Dropout
    # What worked: Have the dropout in between fully connected layers
    conv_layer = tf.nn.dropout(conv_layer, keep_prob)
    
    num_outputs_fc = 64
    conv_layer = fully_conn(conv_layer, num_outputs_fc)
    

    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    
    # TODO: return output
    
    num_outputs = 10
    conv_layer = output(conv_layer, num_outputs)
   
    return conv_layer
    
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# [conv2d_maxpool] x_tensor.shape (?, 32, 32, 3)
# [conv2d_maxpool] conv_ksize: (8, 8)
# [conv2d_maxpool] conv_num_outputs: 32
# [conv2d_maxpool] conv_strides: (1, 1)
# [conv2d_maxpool] pool_ksize: (2, 2)
# [conv2d_maxpool] pool_strides: (2, 2)
#
# [conv2d_maxpool] x_tensor.shape (?, 16, 16, 32)
# [conv2d_maxpool] conv_ksize: (4, 4)
# [conv2d_maxpool] conv_num_outputs: 64
# [conv2d_maxpool] conv_strides: (1, 1)
# [conv2d_maxpool] pool_ksize: (2, 2)
# [conv2d_maxpool] pool_strides: (2, 2)
#
# [conv2d_maxpool] x_tensor.shape (?, 8, 8, 64)
# [conv2d_maxpool] conv_ksize: (2, 2)
# [conv2d_maxpool] conv_num_outputs: 256
# [conv2d_maxpool] conv_strides: (1, 1)
# [conv2d_maxpool] pool_ksize: (2, 2)
# [conv2d_maxpool] pool_strides: (2, 2)
#
# [conv2d_maxpool] x_tensor.shape (?, 32, 32, 3)
# [conv2d_maxpool] conv_ksize: (8, 8)
# [conv2d_maxpool] conv_num_outputs: 32
# [conv2d_maxpool] conv_strides: (1, 1)
# [conv2d_maxpool] pool_ksize: (2, 2)
# [conv2d_maxpool] pool_strides: (2, 2)
#
# [conv2d_maxpool] x_tensor.shape (?, 16, 16, 32)
# [conv2d_maxpool] conv_ksize: (4, 4)
# [conv2d_maxpool] conv_num_outputs: 64
# [conv2d_maxpool] conv_strides: (1, 1)
# [conv2d_maxpool] pool_ksize: (2, 2)
# [conv2d_maxpool] pool_strides: (2, 2)
#
# [conv2d_maxpool] x_tensor.shape (?, 8, 8, 64)
# [conv2d_maxpool] conv_ksize: (2, 2)
# [conv2d_maxpool] conv_num_outputs: 256
# [conv2d_maxpool] conv_strides: (1, 1)
# [conv2d_maxpool] pool_ksize: (2, 2)
# [conv2d_maxpool] pool_strides: (2, 2)
#
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    valid_acc = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                loss,
                valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 1024
keep_probability = 0.8

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     3.1102 Validation Accuracy: 0.132200
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.3036 Validation Accuracy: 0.154600
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.2993 Validation Accuracy: 0.097800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.3008 Validation Accuracy: 0.098000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.2462 Validation Accuracy: 0.157200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.1460 Validation Accuracy: 0.218600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.0678 Validation Accuracy: 0.268800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.9659 Validation Accuracy: 0.301200
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.8803 Validation Accuracy: 0.334400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.8113 Validation Accuracy: 0.352400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.7691 Validation Accuracy: 0.360600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.7105 Validation Accuracy: 0.379600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.6683 Validation Accuracy: 0.394400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.6430 Validation Accuracy: 0.406600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.5879 Validation Accuracy: 0.415800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.5507 Validation Accuracy: 0.433000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.4976 Validation Accuracy: 0.443000
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.4730 Validation Accuracy: 0.451000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.4593 Validation Accuracy: 0.456000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.4067 Validation Accuracy: 0.457800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.3852 Validation Accuracy: 0.467000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.3614 Validation Accuracy: 0.462400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.3171 Validation Accuracy: 0.476000
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.2775 Validation Accuracy: 0.490600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.2544 Validation Accuracy: 0.496200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.2202 Validation Accuracy: 0.499600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.2331 Validation Accuracy: 0.494600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.1679 Validation Accuracy: 0.507600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.1452 Validation Accuracy: 0.512000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.1195 Validation Accuracy: 0.506200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.0945 Validation Accuracy: 0.518400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.0624 Validation Accuracy: 0.524800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.0224 Validation Accuracy: 0.522200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.9951 Validation Accuracy: 0.529200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.9833 Validation Accuracy: 0.523600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.0012 Validation Accuracy: 0.522000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.9433 Validation Accuracy: 0.532000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.9281 Validation Accuracy: 0.529800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.8733 Validation Accuracy: 0.538800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.8697 Validation Accuracy: 0.543400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.8349 Validation Accuracy: 0.543000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.8079 Validation Accuracy: 0.547600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.7990 Validation Accuracy: 0.542800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.7891 Validation Accuracy: 0.544200
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.7673 Validation Accuracy: 0.540400
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.7269 Validation Accuracy: 0.543000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.7206 Validation Accuracy: 0.550800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.7816 Validation Accuracy: 0.536600
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.6986 Validation Accuracy: 0.545000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.7032 Validation Accuracy: 0.539800

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.9100 Validation Accuracy: 0.094800
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.3534 Validation Accuracy: 0.125600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.2875 Validation Accuracy: 0.129400
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.2907 Validation Accuracy: 0.120200
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.2748 Validation Accuracy: 0.157600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2394 Validation Accuracy: 0.181200
# Epoch  2, CIFAR-10 Batch 2:  Loss:     2.1703 Validation Accuracy: 0.193200
# Epoch  2, CIFAR-10 Batch 3:  Loss:     2.0642 Validation Accuracy: 0.232000
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.9683 Validation Accuracy: 0.270600
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.9113 Validation Accuracy: 0.300200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.9150 Validation Accuracy: 0.301400
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.8601 Validation Accuracy: 0.348400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.7698 Validation Accuracy: 0.364000
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.7289 Validation Accuracy: 0.377200
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.7045 Validation Accuracy: 0.376600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.7173 Validation Accuracy: 0.388000
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.6550 Validation Accuracy: 0.421800
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.5830 Validation Accuracy: 0.416000
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.5544 Validation Accuracy: 0.431400
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.5550 Validation Accuracy: 0.439000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.5612 Validation Accuracy: 0.435000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.5233 Validation Accuracy: 0.455600
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.4509 Validation Accuracy: 0.458800
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.4331 Validation Accuracy: 0.462800
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.4476 Validation Accuracy: 0.471000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.4382 Validation Accuracy: 0.467600
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.4223 Validation Accuracy: 0.473400
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.3631 Validation Accuracy: 0.476600
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.3589 Validation Accuracy: 0.493800
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.3386 Validation Accuracy: 0.495400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.3560 Validation Accuracy: 0.491200
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.4044 Validation Accuracy: 0.484200
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.3032 Validation Accuracy: 0.494400
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.2861 Validation Accuracy: 0.508000
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.2772 Validation Accuracy: 0.512800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.2789 Validation Accuracy: 0.515400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.3095 Validation Accuracy: 0.505800
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.2331 Validation Accuracy: 0.519400
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.2442 Validation Accuracy: 0.518400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.2429 Validation Accuracy: 0.532400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.2484 Validation Accuracy: 0.522400
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.2922 Validation Accuracy: 0.517600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.2110 Validation Accuracy: 0.524600
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.1914 Validation Accuracy: 0.536600
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.2124 Validation Accuracy: 0.533400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.2208 Validation Accuracy: 0.538800
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.2012 Validation Accuracy: 0.534200
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.1459 Validation Accuracy: 0.544600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.1385 Validation Accuracy: 0.544800
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.1591 Validation Accuracy: 0.551400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.1749 Validation Accuracy: 0.543200
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.1530 Validation Accuracy: 0.549000
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.1100 Validation Accuracy: 0.551800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.0881 Validation Accuracy: 0.554000
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.1021 Validation Accuracy: 0.567400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.1492 Validation Accuracy: 0.552800
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.1308 Validation Accuracy: 0.557800
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.0499 Validation Accuracy: 0.565000
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.0561 Validation Accuracy: 0.562200
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.0595 Validation Accuracy: 0.569000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.0894 Validation Accuracy: 0.565200
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.0775 Validation Accuracy: 0.569400
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.0081 Validation Accuracy: 0.580600
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.0007 Validation Accuracy: 0.579600
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.0486 Validation Accuracy: 0.571600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.0581 Validation Accuracy: 0.575400
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.0351 Validation Accuracy: 0.578200
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.9643 Validation Accuracy: 0.585800
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.9851 Validation Accuracy: 0.580400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.0165 Validation Accuracy: 0.582000
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.0052 Validation Accuracy: 0.589800
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.0261 Validation Accuracy: 0.578600
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.9402 Validation Accuracy: 0.588400
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.9417 Validation Accuracy: 0.588800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.9688 Validation Accuracy: 0.597400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.9770 Validation Accuracy: 0.594400
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.9942 Validation Accuracy: 0.584400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.9138 Validation Accuracy: 0.591000
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.9486 Validation Accuracy: 0.583400
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.9507 Validation Accuracy: 0.594000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.9392 Validation Accuracy: 0.602600
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.9634 Validation Accuracy: 0.585000
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.8936 Validation Accuracy: 0.591600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.9101 Validation Accuracy: 0.584000
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.9117 Validation Accuracy: 0.600200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.9048 Validation Accuracy: 0.604400
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.9288 Validation Accuracy: 0.591600
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.9010 Validation Accuracy: 0.593200
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.8850 Validation Accuracy: 0.601200
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.8911 Validation Accuracy: 0.608600
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.8757 Validation Accuracy: 0.607000
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.9263 Validation Accuracy: 0.591200
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.8315 Validation Accuracy: 0.608800
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.8329 Validation Accuracy: 0.609800
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.8411 Validation Accuracy: 0.618000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.8476 Validation Accuracy: 0.619200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.8771 Validation Accuracy: 0.606000
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.8118 Validation Accuracy: 0.616000
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.8233 Validation Accuracy: 0.601800
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.8207 Validation Accuracy: 0.615800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.8103 Validation Accuracy: 0.618000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.8334 Validation Accuracy: 0.607600
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.7788 Validation Accuracy: 0.610200
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.7860 Validation Accuracy: 0.611800
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.7901 Validation Accuracy: 0.626000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.7851 Validation Accuracy: 0.625400
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.7897 Validation Accuracy: 0.619000
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.8061 Validation Accuracy: 0.599600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.7655 Validation Accuracy: 0.614000
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.7697 Validation Accuracy: 0.625400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.7567 Validation Accuracy: 0.630800
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.7615 Validation Accuracy: 0.634000
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.7603 Validation Accuracy: 0.611400
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.7541 Validation Accuracy: 0.611400
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.7405 Validation Accuracy: 0.631200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.7322 Validation Accuracy: 0.629200
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.7305 Validation Accuracy: 0.641400
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.7312 Validation Accuracy: 0.616200
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.7298 Validation Accuracy: 0.618400
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.7154 Validation Accuracy: 0.630800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.7018 Validation Accuracy: 0.632200
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.7091 Validation Accuracy: 0.636200
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.7065 Validation Accuracy: 0.620000
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.7146 Validation Accuracy: 0.611600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.7005 Validation Accuracy: 0.629200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.6836 Validation Accuracy: 0.636400
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.6759 Validation Accuracy: 0.639000
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.6766 Validation Accuracy: 0.628600
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.6961 Validation Accuracy: 0.613400
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.6821 Validation Accuracy: 0.634600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.7152 Validation Accuracy: 0.621000
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.6869 Validation Accuracy: 0.632400
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.6373 Validation Accuracy: 0.637600
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.6575 Validation Accuracy: 0.625200
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.6359 Validation Accuracy: 0.640200
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.6403 Validation Accuracy: 0.638000
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.6638 Validation Accuracy: 0.637200
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.6360 Validation Accuracy: 0.640000
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.6280 Validation Accuracy: 0.636400
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.6087 Validation Accuracy: 0.642400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.6201 Validation Accuracy: 0.649000
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.6717 Validation Accuracy: 0.627200
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.6181 Validation Accuracy: 0.636600
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.6319 Validation Accuracy: 0.634600
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.6070 Validation Accuracy: 0.641000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.6047 Validation Accuracy: 0.638400
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.6149 Validation Accuracy: 0.635400
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.5743 Validation Accuracy: 0.644200
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.6337 Validation Accuracy: 0.623600
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.5812 Validation Accuracy: 0.650200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.6052 Validation Accuracy: 0.633800
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.5892 Validation Accuracy: 0.648000
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.6025 Validation Accuracy: 0.632000
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.5818 Validation Accuracy: 0.634000
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.5604 Validation Accuracy: 0.643800
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.5448 Validation Accuracy: 0.643200
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.5686 Validation Accuracy: 0.652600
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.5422 Validation Accuracy: 0.650400
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.5429 Validation Accuracy: 0.635200
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.5525 Validation Accuracy: 0.633800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.5432 Validation Accuracy: 0.641200
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.5550 Validation Accuracy: 0.653400
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.5258 Validation Accuracy: 0.639200
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.5195 Validation Accuracy: 0.641600
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.5634 Validation Accuracy: 0.622800
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.5377 Validation Accuracy: 0.642800
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.5380 Validation Accuracy: 0.644000
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.5105 Validation Accuracy: 0.649800
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.5067 Validation Accuracy: 0.646200
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.5360 Validation Accuracy: 0.634600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.5306 Validation Accuracy: 0.634000
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.5238 Validation Accuracy: 0.650600
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.4720 Validation Accuracy: 0.645400
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.5186 Validation Accuracy: 0.639000
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.4808 Validation Accuracy: 0.644400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.5279 Validation Accuracy: 0.625200
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.5420 Validation Accuracy: 0.643200
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.4653 Validation Accuracy: 0.651200
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.4801 Validation Accuracy: 0.652000
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.4712 Validation Accuracy: 0.652200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.4435 Validation Accuracy: 0.651800
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.4888 Validation Accuracy: 0.655400
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.4605 Validation Accuracy: 0.647800
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.4328 Validation Accuracy: 0.655800
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.4444 Validation Accuracy: 0.660600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.4283 Validation Accuracy: 0.653600
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.4571 Validation Accuracy: 0.655400
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.4179 Validation Accuracy: 0.649800
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.4477 Validation Accuracy: 0.636600
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.4384 Validation Accuracy: 0.642800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.4083 Validation Accuracy: 0.652400
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.4471 Validation Accuracy: 0.653600
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.4160 Validation Accuracy: 0.645400
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.4287 Validation Accuracy: 0.632400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.4219 Validation Accuracy: 0.650000
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.3986 Validation Accuracy: 0.656600
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.4247 Validation Accuracy: 0.648400
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.3921 Validation Accuracy: 0.659000
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.3847 Validation Accuracy: 0.649400
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.3889 Validation Accuracy: 0.653000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.3941 Validation Accuracy: 0.655800
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.3989 Validation Accuracy: 0.650800
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.3710 Validation Accuracy: 0.660600
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.3506 Validation Accuracy: 0.652400
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.3659 Validation Accuracy: 0.648200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.3721 Validation Accuracy: 0.658600
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.3663 Validation Accuracy: 0.654400
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.3465 Validation Accuracy: 0.661200
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.3440 Validation Accuracy: 0.653800
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.3495 Validation Accuracy: 0.653600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.3362 Validation Accuracy: 0.662400
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.3440 Validation Accuracy: 0.655800
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.3110 Validation Accuracy: 0.666200
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.3296 Validation Accuracy: 0.648600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.3357 Validation Accuracy: 0.655200
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.3276 Validation Accuracy: 0.667200
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.3100 Validation Accuracy: 0.661600
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.3155 Validation Accuracy: 0.659600
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.2857 Validation Accuracy: 0.661000
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.3066 Validation Accuracy: 0.658200
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.3044 Validation Accuracy: 0.662400
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.3036 Validation Accuracy: 0.654400
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.2918 Validation Accuracy: 0.667000
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.2783 Validation Accuracy: 0.663200
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.3037 Validation Accuracy: 0.656200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.2821 Validation Accuracy: 0.670000
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.2792 Validation Accuracy: 0.666000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.2988 Validation Accuracy: 0.656600
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.2651 Validation Accuracy: 0.672400
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.2803 Validation Accuracy: 0.668800
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.2815 Validation Accuracy: 0.662200
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.2761 Validation Accuracy: 0.652200
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.2830 Validation Accuracy: 0.666400
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.2613 Validation Accuracy: 0.659800
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.2703 Validation Accuracy: 0.657400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.2622 Validation Accuracy: 0.663800
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.2520 Validation Accuracy: 0.657400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.2744 Validation Accuracy: 0.652800
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.2553 Validation Accuracy: 0.657200
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.2727 Validation Accuracy: 0.650600
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.2422 Validation Accuracy: 0.667800
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.2453 Validation Accuracy: 0.656600
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.2409 Validation Accuracy: 0.661200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.2294 Validation Accuracy: 0.656400
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.2580 Validation Accuracy: 0.660600
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.2195 Validation Accuracy: 0.666600
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.2329 Validation Accuracy: 0.658800
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.2371 Validation Accuracy: 0.651600
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.2309 Validation Accuracy: 0.655400
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.2503 Validation Accuracy: 0.652000

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6504723310470581

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
